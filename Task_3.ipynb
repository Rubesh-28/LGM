# %% [markdown]
# #Data Science Intern at Let's Grow More LGMVIP
# #Task 3 : Develop A Neural Network That Can Read Handwriting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

# %%
mnist= tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)),
                                    tf.keras.layers.Dense(128, activation ='relu'),
                                    tf.keras.layers.Dense(10, activation='softmax')])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(),
              loss ='sparse_categorical_crossentropy',
            metrics=['accuracy'])

# %%
model.fit(x_train,y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 3ms/step - loss: 0.2569 - accuracy: 0.9274
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1128 - accuracy: 0.9667
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0771 - accuracy: 0.9769
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0583 - accuracy: 0.9822
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0449 - accuracy: 0.9862

# %%
model.fit(x_train,y_train, epochs=9)
# Out:
# Epoch 1/9
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0351 - accuracy: 0.9891
# Epoch 2/9
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0288 - accuracy: 0.9913
# Epoch 3/9
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0227 - accuracy: 0.9926
# Epoch 4/9
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0196 - accuracy: 0.9939
# Epoch 5/9
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0166 - accuracy: 0.9948
# Epoch 6/9
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0126 - accuracy: 0.9960
# Epoch 7/9
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0114 - accuracy: 0.9965
# Epoch 8/9
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0105 - accuracy: 0.9969
# Epoch 9/9
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0084 - accuracy: 0.9973

# %%
print(model.evaluate(x_test,y_test))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0878 - accuracy: 0.9806
# [0.08781620115041733, 0.9805999994277954]

# %%
history=model.fit(x_train,y_train,epochs=10,batch_size=32,validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0081 - val_accuracy: 0.9973
# Epoch 2/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0102 - val_accuracy: 0.9965
# Epoch 3/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0103 - val_accuracy: 0.9965
# Epoch 4/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0130 - val_accuracy: 0.9952
# Epoch 5/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.0113 - val_accuracy: 0.9962
# Epoch 6/10
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0146 - val_accuracy: 0.9948
# Epoch 7/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0136 - val_accuracy: 0.9955
# Epoch 8/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0173 - val_accuracy: 0.9935
# Epoch 9/10
# 1688/1688 [==============================] - 5s 3ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0189 - val_accuracy: 0.9952
# Epoch 10/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.0185 - val_accuracy: 0.9940

# %%
plt.title("Accuracy and Loss")
plt.xlabel("Epoch")
plt.ylabel("acc/Loss")
plt.plot(history.history['accuracy'],label='acc')
plt.plot(history.history["val_accuracy"],label='val')
plt.show()

# %%
plt.title("Accuracy and Loss")
plt.xlabel("Epoch")
plt.ylabel("acc/Loss")
plt.plot(history.history['loss'],label='acc')
plt.plot(history.history["val_loss"],label='val')
plt.show()

# %%
plt.imshow(np.squeeze(x_test[0]),cmap="Reds")

# %%
prediction=model.predict(x_test)
print(np.argmax(prediction[0]))
# Out:
# 313/313 [==============================] - 1s 2ms/step
# 7

# %%
plt.imshow(np.squeeze(x_test[1]),cmap="Reds")

# %%
prediction=model.predict(x_test)
print(np.argmax(prediction[1]))
# Out:
# 313/313 [==============================] - 1s 2ms/step
# 2
